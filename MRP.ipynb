# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
production=pd.read_csv("Production_2.csv")
Product=pd.read_csv("Products.csv")
sales=pd.read_csv("Sales.csv")
stores=pd.read_csv("Stores.csv")

# %%
production.head(5)
# Out:
#    production_id  product_id production_date    batch_no  quantity_produced  \
# 0           6842         130      2026-01-27  BATCH-5464                889
# 1           6665         102      2026-01-16  BATCH-9269                757
# 2           6635          46      2025-03-08  BATCH-8734                617
# 3           6386          80      2026-01-04  BATCH-8247                358
# 4           5665           5      2026-01-11  BATCH-6358                338
#
#    raw_material_cost  labor_cost  machine_hours  defective_units  \
# 0            8762.58     1942.38           7.13               41
# 1            6651.76      769.45           9.67               23
# 2            4761.74     1950.42           8.42               25
# 3            1977.55     1341.53           3.36               43
# 4            8768.20      711.16           4.77               24
#
#    quantity_sold    price
# 0            267  1997.31
# 1            215  1263.27
# 2            345  4253.34
# ...

# %% [raw]
# production.isnull().sum()

# %%
production.dtypes
# Out:
# production_id          int64
# product_id             int64
# production_date          str
# batch_no                 str
# quantity_produced      int64
# raw_material_cost    float64
# labor_cost           float64
# machine_hours        float64
# defective_units        int64
# quantity_sold          int64
# price                float64
# dtype: object

# %%
production.describe()
# Out:
#        production_id   product_id  quantity_produced  raw_material_cost  \
# count    1499.000000  1499.000000        1499.000000        1499.000000
# mean     6450.695797    73.847231         557.913276        5018.510447
# std       553.241162    44.078353         254.644031        2324.753895
# min      5500.000000     1.000000         100.000000        1005.900000
# 25%      5963.500000    35.000000         341.000000        2990.685000
# 50%      6448.000000    73.000000         563.000000        4943.700000
# 75%      6953.500000   113.000000         776.500000        7002.540000
# max      7400.000000   150.000000        1000.000000        8994.720000
#
#         labor_cost  machine_hours  defective_units  quantity_sold        price
# count  1499.000000    1499.000000      1499.000000    1499.000000  1499.000000
# mean   1243.499233       5.587111        25.099400     354.853903  2517.526684
# std     432.783637       2.589402        14.799871     199.098903  1441.884257
# ...

# %%
(production.isnull().sum()/len(production))*100
# Out:
# production_id        0.0
# product_id           0.0
# production_date      0.0
# batch_no             0.0
# quantity_produced    0.0
# raw_material_cost    0.0
# labor_cost           0.0
# machine_hours        0.0
# defective_units      0.0
# quantity_sold        0.0
# price                0.0
# dtype: float64

# %%
##Q1 = df["revenue"].quantile(0.25)
#Q3 = df["revenue"].quantile(0.75)
#IQR = Q3 - Q1
#lower_bound = Q1 - 1.5 * IQR
#upper_bound = Q3 + 1.5 * IQR

# %%
sns.boxplot(x=production["production_id"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=production["product_id"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=production["production_date"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=production["quantity_sold"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=production["price"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=production["labor_cost"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
production.dtypes
# Out:
# production_id          int64
# product_id             int64
# production_date          str
# batch_no                 str
# quantity_produced      int64
# raw_material_cost    float64
# labor_cost           float64
# machine_hours        float64
# defective_units        int64
# quantity_sold          int64
# price                float64
# dtype: object

# %%
df1["production_date"]=df1["production_date"].astype("float").astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df1["production_date"]=df1["production_date"].astype("float").astype("int")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
df1.production_date.dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
production=production. astype ({
    "production_date":"int",
    "batch_no": "int",
    "raw_material_cost": "int",
    "labor_cost": "int",
    "machine_hours": "int",
    "price": "int" 
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 production=production. astype ({
#       2     "production_date":"int",
#       3     "batch_no": "int",
#       4     "raw_material_cost": "int",
#       5     "labor_cost": "int",
#       6     "machine_hours": "int",
#       7     "price": "int"
#       8 })
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6520, in NDFrame.astype(self, dtype, copy, errors)
#    6518 else:
#    6519     try:
# -> 6520         res_col = col.astype(dtype=cdt, errors=errors)
#    6521     except ValueError as ex:
#    6522         ex.args = (
#    6523             f"{ex}: Error while type casting for column '{col_name}'",
#    6524         )
#
# ...

# %%
df1=production

# %%
df1
# Out:
#       production_id  product_id production_date    batch_no  \
# 0              6842         130      2026-01-27  BATCH-5464
# 1              6665         102      2026-01-16  BATCH-9269
# 2              6635          46      2025-03-08  BATCH-8734
# 3              6386          80      2026-01-04  BATCH-8247
# 4              5665           5      2026-01-11  BATCH-6358
# ...             ...         ...             ...         ...
# 1494           6306         144      2025-04-19  BATCH-1375
# 1495           6796          19      2025-04-04  BATCH-7133
# 1496           7058          83      2025-07-21  BATCH-1461
# 1497           6821         133      2026-01-28  BATCH-1939
# 1498           6428          47      2026-01-11  BATCH-7476
#
#       quantity_produced  raw_material_cost  labor_cost  machine_hours  \
# 0                   889            8762.58     1942.38           7.13
# 1                   757            6651.76      769.45           9.67
# ...

# %%
df1["production_date"] = df1["production_date"].str.replace(',',)
df1["production_date"] = df1["production_date"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df1["production_date"] = df1["production_date"].str.replace(',',)
#       2 df1["production_date"] = df1["production_date"].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\strings\accessor.py:142, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     137     msg = (
#     138         f"Cannot use .str.{func_name} with values of "
#     139         f"inferred dtype '{self._inferred_dtype}'."
#     140     )
#     141     raise TypeError(msg)
# --> 142 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\strings\accessor.py:1790, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
# ...
